# %%
from pachamama import terra

# %%
terra.cvmass(feh=0.1, mass=1)
# Out:
# 0.0311040253

# %%
terra.pacha(feh=0.164, mass=1,  Mcon=0.01, data_input='obs_abd.csv')
# Out:
# searching the best solution: 100%|██████████| 26/26 [00:14<00:00,  1.84it/s]
#  chi2  Nmet  Nearth  Total_mass
#  5.20  7.00    2.40        9.40

# %%
terra.pacha(feh=0.164, mass=1,  Mcon=0.01, data_input='obs_abd.csv',
           data_output='HIP71726')
# Out:
# exploring data: 100%|██████████| 26/26 [00:03<00:00,  7.10it/s]
#  chi2  Nmet  Nearth  Total_mass
#  5.20  7.00    2.40        9.40
